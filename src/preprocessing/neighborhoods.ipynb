# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import h3pandas

neigh_gpd = gpd.read_file(
    'https://services5.arcgis.com/GfwWNkhOj9bNBqoJ/arcgis/rest/services/Neighborhood_Names/FeatureServer/0/query?where=1=1&outFields=*&outSR=4326&f=pgeojson')

# %%
neigh_gpd = neigh_gpd.h3.geo_to_h3(10)
neigh_gpd = neigh_gpd[neigh_gpd['Stacked'] < 3]

# %%
neigh_gpd.reset_index()[['h3_10', 'Name']].to_csv('../../data/clean/neighborhood_centroids.csv', index=False)

# %%
neigh_gpd.reset_index()
# Out:
#                h3_10  FID           Name  Stacked    AnnoLine1 AnnoLine2  \
# 0    8a2a100140b7fff    1      Wakefield        1    Wakefield
# 1    8a2a100150f7fff    2     Co-op City        2        Co-op      City
# 2    8a2a10015d37fff    3    Eastchester        1  Eastchester
# 3    8a2a100a5187fff    4      Fieldston        1    Fieldston
# 4    8a2a100a545ffff    5      Riverdale        1    Riverdale
# ..               ...  ...            ...      ...          ...       ...
# 292  8a2a10756727fff  302      Stapleton        1    Stapleton
# 293  8a2a10750587fff  303       Rosebank        1     Rosebank
# 294  8a2a10625ccffff  304  West Brighton        2         West  Brighton
# 295  8a2a10625b4ffff  305    Grymes Hill        2       Grymes      Hill
# 296  8a2a1062124ffff  306      Todt Hill        2         Todt      Hill
#
#     AnnoLine3  AnnoAngle        Borough                              GlobalID  \
# ...

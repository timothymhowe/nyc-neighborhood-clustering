# %%
import pandas as pd
import numpy as np
import pyogrio
import contextily as ctx
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [10], in <cell line: 4>()
#       2 import numpy as np
#       3 import pyogrio
# ----> 4 import contextily as ctx
#
# ModuleNotFoundError: No module named 'contextily'

# %%
import geopandas as gpd
import h3pandas
# gdf = gpd.read_file('../data/nyc_mappluto_22v1_shp/MapPLUTO.shp',rows = 100000)

boroughs = gpd.read_file('../data/raw/geoJSON/NYC/boroughs.geojson')
# Out:
#    BoroCode       BoroName    Shape_Leng    Shape_Area  \
# 0         5  Staten Island  330385.03697  1.623853e+09
# 1         4         Queens  861038.47930  3.049947e+09
# 2         3       Brooklyn  726568.94634  1.959432e+09
# 3         1      Manhattan  358532.95642  6.364422e+08
# 4         2          Bronx  464517.89055  1.186804e+09
#
#                                             geometry
# 0  MULTIPOLYGON (((-74.05051 40.56642, -74.05047 ...
# 1  MULTIPOLYGON (((-73.83668 40.59495, -73.83678 ...
# 2  MULTIPOLYGON (((-73.86706 40.58209, -73.86769 ...
# 3  MULTIPOLYGON (((-74.01093 40.68449, -74.01193 ...
# 4  MULTIPOLYGON (((-73.89681 40.79581, -73.89694 ...

# %%
# %matplotlib inline
boroughs.plot(column='BoroName',cmap='Pastel1',categorical=True,figsize=(8,8))
# Out:
# <AxesSubplot:>

# %%
import sys
# !conda install --yes --prefix {sys.prefix} contextily
# Out:
# ...
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/noarch::geopandas==0.11.1=pyhd8ed1ab_0
#   - conda-forge/noarch::h3pandas==0.2.3=pyhd8ed1ab_1
#   - conda-forge/noarch::geoplot==0.3.0=py_0
# failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: - ^C
# failed with repodata from current_repodata.json, will retry with next repodata source.
#
# CondaError: KeyboardInterrupt

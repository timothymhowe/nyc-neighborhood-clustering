# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../data/raw/cb10_cb20/tab2010_tab2020_st36_ny.txt', sep='|')

# %%
df
# Out:
#         STATE_2010  COUNTY_2010  TRACT_2010  BLK_2010  BLKSF_2010  \
# 0               34           31      256802      1010         NaN
# 1               36            1         100      1000         NaN
# 2               36            1         100      1001         NaN
# 3               36            1         100      1002         NaN
# 4               36            1         100      1003         NaN
# ...            ...          ...         ...       ...         ...
# 382507          36          123      150500      4022         NaN
# 382508          36          123      150500      4023         NaN
# 382509          36          123      150500      4024         NaN
# 382510          36          123      150500      4025         NaN
# 382511          36          123      150500      4026         NaN
#
#         AREALAND_2010  AREAWATER_2010 BLOCK_PART_FLAG_O  STATE_2020  \
# 0                  23               0               NaN          36
# ...
